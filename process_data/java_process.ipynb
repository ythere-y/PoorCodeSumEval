# %%
from typing import List
from sympy import root
from tree_sitter import Language, Parser, Node

import random

import os
from datasets import load_dataset, Dataset, load_from_disk
from statistics import python_dict, java_dict, go_dict
from tqdm.notebook import tqdm
from colorama import Fore, Back, Style
import pandas as pd
import javalang
from process_data.RobustCodeSumJava import JavaParser

import parso

from utils import ParserUtils
import os

os.chdir("/data2/huchao/11.novels/bigcode-evaluation-harness")

# %%
DATASET_PATH = "/data2/huchao/11.novels/download/code_x_glue_ct_code_to_text"

dataset = load_dataset(DATASET_PATH, "java")["test"]
print(f"load data from code search net, size: {dataset.shape}")
self_lang_str = "java"
self_langurage = Language("/data2/huchao/11.novels/bigcode-evaluation-harness/process_data/build/my-languages.so", self_lang_str)
self_parser = Parser()
self_parser.set_language(self_langurage)
# Out:
# load data from code search net, size: (10955, 12)
# /home/huchao/micromamba/lib/python3.9/site-packages/datasets/load.py:922: FutureWarning: The repository for code_x_glue_ct_code_to_text contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /data2/huchao/11.novels/download/code_x_glue_ct_code_to_text/code_x_glue_ct_code_to_text.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
# init the parser

# %% [markdown]
# ## FNE: 替换函数名为v0

# %%
row = dataset[10]
code_string = row["code"]
code_string = JavaParser.wrap_java_code(code_string)
print(code_string)

tree = self_parser.parse(bytes(code_string, "utf8"))
root_node = tree.root_node
# Out:
# class CLS {
# @CheckReturnValue
#     @NonNull
#     @SchedulerSupport(SchedulerSupport.NONE)
#     public static <T> Maybe<T> fromSingle(SingleSource<T> singleSource) {
#         ObjectHelper.requireNonNull(singleSource, "singleSource is null");
#         return RxJavaPlugins.onAssembly(new MaybeFromSingle<T>(singleSource));
#     }
# }

# %%
def_node = JavaParser.get_method_def_node(tree)
blob = code_string
print(def_node.text.decode("utf8"))

method_identifier = def_node.child_by_field_name("name")

new_code_string = ParserUtils.replace_from_span(
    (method_identifier.start_point, method_identifier.end_point), blob, "v0"
)
new_code_string =unwrap_java_code(new_code_string)
print(new_code_string)
# Out:
# @CheckReturnValue
#     @NonNull
#     @SchedulerSupport(SchedulerSupport.NONE)
#     public static <T> Maybe<T> fromSingle(SingleSource<T> singleSource) {
#         ObjectHelper.requireNonNull(singleSource, "singleSource is null");
#         return RxJavaPlugins.onAssembly(new MaybeFromSingle<T>(singleSource));
#     }
# @CheckReturnValue
#     @NonNull
#     @SchedulerSupport(SchedulerSupport.NONE)
#     public static <T> Maybe<T> v0(SingleSource<T> singleSource) {
#         ObjectHelper.requireNonNull(singleSource, "singleSource is null");
#         return RxJavaPlugins.onAssembly(new MaybeFromSingle<T>(singleSource));
#     }

# %% [markdown]
# ## OOS：计算交换

# %%
from process_data.RobustCodeSum import PythonParsoParser

row = dataset[10]
code_string = row["code"]
print(code_string)

parsed_ast = parso.parse(code_string)
if len(list(parsed_ast.iter_funcdefs())) == 0:
    # continue
    exit(0)
func_node = list(parsed_ast.iter_funcdefs())[0]
identifier_name_to_nodes = PythonParsoParser.get_all_identifers(func_node)




new_code_string = func_node.get_code()
# print(new_code_string)
# Out:
# def get_video_url_from_video_id(video_id):
#     """Splicing URLs according to video ID to get video details"""
#     # from js
#     data = [""] * 256
#     for index, _ in enumerate(data):
#         t = index
#         for i in range(8):
#             t = -306674912 ^ unsigned_right_shitf(t, 1) if 1 & t else unsigned_right_shitf(t, 1)
#         data[index] = t
#
#     def tmp():
#         rand_num = random.random()
#         path = "/video/urls/v/1/toutiao/mp4/{video_id}?r={random_num}".format(video_id=video_id,
#                                                                               random_num=str(rand_num)[2:])
#         e = o = r = -1
#         i, a = 0, len(path)
#         while i < a:
#             e = ord(path[i])
#             i += 1
#             if e < 128:
#                 r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ e)]
#             else:
#                 if e < 2048:
#                     r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (192 | e >> 6 & 31))]
#                     r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (128 | 63 & e))]
#                 else:
#                     if 55296 <= e < 57344:
#                         e = (1023 & e) + 64
#                         i += 1
#                         o = 1023 & t.url(i)
#                         r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (240 | e >> 8 & 7))]
#                         r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (128 | e >> 2 & 63))]
#                         r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (128 | o >> 6 & 15 | (3 & e) << 4))]
#                         r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (128 | 63 & o))]
#                     else:
#                         r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (224 | e >> 12 & 15))]
#                         r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (128 | e >> 6 & 63))]
#                         r = unsigned_right_shitf(r, 8) ^ data[255 & (r ^ (128 | 63 & e))]
#
#         return "https://ib.365yg.com{path}&s={param}".format(path=path, param=unsigned_right_shitf(r ^ -1, 0))
#
#     while 1:
#         url = tmp()
#         if url.split("=")[-1][0] != "-":  # 参数s不能为负数
#             return url

# %% [markdown]
# ## IRS: 随机调换标识符名字（使用函数片段中已有的标识符名字）

# %%
# 找到所有的identifier_list
# 打乱ide_list的顺序，然后形成对应，确定替换关系(ide -> ide')
# 在code中替换对象，作为混淆结果

from process_data.RobustCodeSum import PythonParsoParser
from process_data.utils import DataUtils

row = dataset[0]

row = dataset[0]
code_string = row["code"]

tree = self_parser.parse(bytes(code_string, "utf8"))
root_node = tree.root_node

# 使用traverse方法来获取所有的identifier
all_ide_list = []
ParserUtils.traverse_type(root_node, all_ide_list, "identifier")

# 继承原来的方法来获取所有对象identifier（主要是要筛去api调用之类的）
target_ide_name_list = JavaParser.get_all_target_ide_name(root_node)

# 两者结合得到所有的name和node对应关系
identifier_dict = {}
for _ide in all_ide_list:
    _name = _ide.text.decode("utf8")
    if _name in target_ide_name_list:
        if not _name in identifier_dict:
            identifier_dict[_name] = [_ide]
        else:
            identifier_dict[_name].append(_ide)

# 生成替换字典
# 匹配,使用zip，使用循环替换的方法来做到打乱效果
replace_dict = dict(zip(target_ide_name_list[:-1], target_ide_name_list[1:]))
replace_dict.update({target_ide_name_list[-1]: target_ide_name_list[0]})


# 替换identifier
nodes_info = []
for identifier, replace_str in replace_dict.items():
    nodes = identifier_dict[identifier]
    for node in nodes:
        nodes_info.append((node, replace_str))
new_blob = ParserUtils.replace_nodes_str(nodes_info, code_string)

new_code_string = JavaParser.unwrap_java_code(new_blob)

DataUtils.display_before_and_after(code_string, new_code_string)
# Out:
# before handle:
# protected final void fastPathOrderedEmit(U value, boolean delayError, Disposable disposable) {
#         final Observer<? super V> observer = downstream;
#         final SimplePlainQueue<U> q = queue;
#
#         if (wip.get() == 0 && wip.compareAndSet(0, 1)) {
#             if (q.isEmpty()) {
#                 accept(observer, value);
#                 if (leave(-1) == 0) {
#                     return;
#                 }
#             } else {
#                 q.offer(value);
#             }
#         } else {
#             q.offer(value);
#             if (!enter()) {
#                 return;
#             }
#         }
#         QueueDrainHelper.drainLoop(q, observer, delayError, disposable, this);
#     }
# after handle:
# nal void value(U delayError, boolean disposable, Disposable observer) {
#         final Observer<? super V> downstream = q;
#         final SimplePlainQueue<U> queue = fastPathOrderedEmit;
#
#         if (wip.get() == 0 && wip.compareAndSet(0, 1)) {
#             if (queue.isEmpty()) {
#                 accept(downstream, delayError);
#                 if (leave(-1) == 0) {
#                     return;
#                 }
#             } else {
#                 queue.offer(delayError);
#             }
#         } else {
#             queue.offer(delayError);
#             if (!enter()) {
#                 return;
#             }
#         }
#         QueueDrainHelper.drainLoop(queue, downstream, disposable, observer, this);

# %% [markdown]
# ## IHR：使用代码高频词替换标识符

# %%
# 找到所有的identifier_list
# 对于每一个目标ide,去高频词库中随机找一个词出来替换(ide,random_word)
# 同时不同ide的替换词不能相同
# 在code中替换对象，作为混淆结果


# 找到所有的identifier_list
# 打乱ide_list的顺序，然后形成对应，确定替换关系(ide -> ide')
# 在code中替换对象，作为混淆结果

from process_data.RobustCodeSum import PythonParsoParser
from process_data.utils import DataUtils

row = dataset[0]

row = dataset[0]
code_string = row["code"]

tree = self_parser.parse(bytes(code_string, "utf8"))
root_node = tree.root_node

# 使用traverse方法来获取所有的identifier
all_ide_list = []
ParserUtils.traverse_type(root_node, all_ide_list, "identifier")

# 继承原来的方法来获取所有对象identifier（主要是要筛去api调用之类的）
target_ide_name_list = JavaParser.get_all_target_ide_name(root_node)

# 两者结合得到所有的name和node对应关系
identifier_dict = {}
for _ide in all_ide_list:
    _name = _ide.text.decode("utf8")
    if _name in target_ide_name_list:
        if not _name in identifier_dict:
            identifier_dict[_name] = [_ide]
        else:
            identifier_dict[_name].append(_ide)


# 获取高频词数组
high_freq_list = [word[0] for word in python_dict]


# 对所有identifier随机匹配一个高频词，且不能有重复的
# 做法是，先shuffle high_freq_dict，然后按顺序匹配

# shuffle
random.shuffle(high_freq_list)

# 使用匹配的方式，生成替换字典
replace_dict = {}
for identifier in target_ide_name_list:
    replace_dict[identifier] = high_freq_list.pop()


# 替换identifier
nodes_info = []
for identifier, replace_str in replace_dict.items():
    nodes = identifier_dict[identifier]
    for node in nodes:
        nodes_info.append((node, replace_str))
new_blob = ParserUtils.replace_nodes_str(nodes_info, code_string)

new_code_string = JavaParser.unwrap_java_code(new_blob)

DataUtils.display_before_and_after(code_string, new_code_string)
# Out:
# before handle:
# protected final void fastPathOrderedEmit(U value, boolean delayError, Disposable disposable) {
#         final Observer<? super V> observer = downstream;
#         final SimplePlainQueue<U> q = queue;
#
#         if (wip.get() == 0 && wip.compareAndSet(0, 1)) {
#             if (q.isEmpty()) {
#                 accept(observer, value);
#                 if (leave(-1) == 0) {
#                     return;
#                 }
#             } else {
#                 q.offer(value);
#             }
#         } else {
#             q.offer(value);
#             if (!enter()) {
#                 return;
#             }
#         }
#         QueueDrainHelper.drainLoop(q, observer, delayError, disposable, this);
#     }
# after handle:
# nal void i(U end, boolean filename, Disposable event) {
#         final Observer<? super V> r = start;
#         final SimplePlainQueue<U> index = get;
#
#         if (wip.get() == 0 && wip.compareAndSet(0, 1)) {
#             if (index.isEmpty()) {
#                 accept(r, end);
#                 if (leave(-1) == 0) {
#                     return;
#                 }
#             } else {
#                 index.offer(end);
#             }
#         } else {
#             index.offer(end);
#             if (!enter()) {
#                 return;
#             }
#         }
#         QueueDrainHelper.drainLoop(index, r, filename, event, this);

# %% [markdown]
# ## IOE:标识符变成v0，v1…，函数名也会变

# %%
# 找到所有的identifier_list
# 将其中的100%作为替换目标
# 替换identifier_list，每个ide给予一个对象(v_n)
# 在code中替换对象，作为混淆结果

from process_data.RobustCodeSum import PythonParsoParser
from process_data.utils import DataUtils

row = dataset[323]
code_string = row["code"]
# print(code_string)

tree = self_parser.parse(bytes(code_string, "utf8"))
root_node = tree.root_node

# 使用traverse方法来获取所有的identifier
all_ide_list = []
ParserUtils.traverse_type(root_node, all_ide_list, "identifier")
# for _ide in all_ide_list:
#     print(_ide.text.decode("utf8"))
# 继承原来的方法来获取所有对象identifier（主要是要筛去api调用之类的）
target_ide_name_list = []
nodes = [root_node]
while len(nodes) > 0:
    cur_node = nodes.pop(0)
    if cur_node.type == "ERROR":
        print(code_string)
        continue

    if (
        cur_node.type == "variable_declarator"
        or cur_node.type == "formal_parameter"
        or cur_node.type == "method_declaration"
        or cur_node.type == "constructor_declaration"
        or cur_node.type == "assignment_expression"
    ):
        for child in cur_node.children:
            if child.type == "identifier":
                identifier_string = child.text.decode("utf8")
                if not identifier_string in target_ide_name_list:
                    target_ide_name_list.append(identifier_string)
    for child in cur_node.children:
        nodes.append(child)

# 两者结合得到所有的name和node对应关系
identifier_dict = {}
for _ide in all_ide_list:
    _name = _ide.text.decode("utf8")
    if _name in target_ide_name_list:
        if not _name in identifier_dict:
            identifier_dict[_name] = [_ide]
        else:
            identifier_dict[_name].append(_ide)
# for key in identifier_dict:
#     print(key, len(identifier_dict[key]))

# 生成替换字典
replace_dict = {}
for i, ide_name in enumerate(target_ide_name_list):
    replace_dict[ide_name] = f"v{i}"

# 替换identifier
nodes_info = []
for identifier, replace_str in replace_dict.items():
    nodes = identifier_dict[identifier]
    for node in nodes:
        nodes_info.append((node, replace_str))
new_blob = ParserUtils.replace_nodes_str(nodes_info, code_string)
new_code_string = JavaParser.unwrap_java_code(new_blob)
DataUtils.display_before_and_after(code_string, new_code_string)
# Out:
# before handle:
# private static boolean overrides(Method a, Method b) {
#     // See JLS section 8.4.8.1
#     int modifiers = b.getModifiers();
#     if (Modifier.isPublic(modifiers) || Modifier.isProtected(modifiers)) {
#       return true;
#     }
#     if (Modifier.isPrivate(modifiers)) {
#       return false;
#     }
#     // b must be package-private
#     return a.getDeclaringClass().getPackage().equals(b.getDeclaringClass().getPackage());
#   }
# after handle:
# ic boolean v0(Method v1, Method v2) {
#     // See JLS section 8.4.8.1
#     int v3 = v2.getModifiers();
#     if (Modifier.isPublic(v3) || Modifier.isProtected(v3)) {
#       return true;
#     }
#     if (Modifier.isPrivate(v3)) {
#       return false;
#     }
#     // b must be package-private
#     return v1.getDeclaringClass().getPackage().equals(v2.getDeclaringClass().getPackage());

# %% [markdown]
# ## HVI:加入无意义的高频次的变量声明

# %%
from process_data.utils import DataUtils

row = dataset[512]
code_string = row["code"]
code_string = JavaParser.wrap_java_code(code_string)
print(code_string)

tree = self_parser.parse(bytes(code_string, "utf8"))
root_node = tree.root_node

# 继承原来的方法来获取所有对象identifier（主要是要筛去api调用之类的）
target_ide_name_list = JavaParser.get_all_target_ide_name(root_node)


insert_list = []
insert_num = 3
for i in range(len(java_dict)):
    if not java_dict[i][0] in target_ide_name_list:
        insert_list.append(java_dict[i][0])
        if len(insert_list) == insert_num:
            break
        
func_body_node = (
    root_node.children[0].children[-1].children[1].child_by_field_name("body")
)
insert_index = random.randint(1, len(func_body_node.children) - 2)
print(f"insert index = {insert_index}")

# 插入在这个child的前面
# 获取这个位置的缩进
insert_indent_count = ParserUtils.get_node_indent_count(func_body_node.children[insert_index],code_string)
print(f"insert indent = {insert_indent_count}")

# 制作插入体
insert_str = ""
for var in insert_list:
    insert_str += f"{' '*insert_indent_count}int {var} = {random.randint(0,100)}\n"
# 最后的位置去掉换行
insert_str = insert_str[:-1]

# 获取这个位置的行号
insert_position = func_body_node.children[insert_index].start_point[0]
print(f"insert line number = {insert_position}")

# 进行插入
body_code_lines = code_string.split("\n")
body_code_lines.insert(insert_position, insert_str)
new_code_string = "\n".join(body_code_lines)

new_code_string = JavaParser.unwrap_java_code(new_code_string)
DataUtils.display_before_and_after(code_string, new_code_string)
# Out:
# class CLS {
# private void doServerShutdown() {
# 		stopConnectionLostTimer();
# 		if( decoders != null ) {
# 			for( WebSocketWorker w : decoders ) {
# 				w.interrupt();
# 			}
# 		}
# 		if( selector != null ) {
# 			try {
# 				selector.close();
# 			} catch ( IOException e ) {
# 				log.error( "IOException during selector.close", e );
# 				onError( null, e );
# 			}
# 		}
# 		if( server != null ) {
# 			try {
# 				server.close();
# 			} catch ( IOException e ) {
# 				log.error( "IOException during server.close", e );
# 				onError( null, e );
# 			}
# 		}
# 	}
# }
# insert index = 3
# insert indent = 8
# insert line number = 8
# before handle:
# class CLS {
# private void doServerShutdown() {
# 		stopConnectionLostTimer();
# 		if( decoders != null ) {
# 			for( WebSocketWorker w : decoders ) {
# 				w.interrupt();
# 			}
# 		}
# 		if( selector != null ) {
# 			try {
# 				selector.close();
# 			} catch ( IOException e ) {
# 				log.error( "IOException during selector.close", e );
# 				onError( null, e );
# 			}
# 		}
# 		if( server != null ) {
# 			try {
# 				server.close();
# 			} catch ( IOException e ) {
# 				log.error( "IOException during server.close", e );
# 				onError( null, e );
# 			}
# 		}
# 	}
# }
# after handle:
# private void doServerShutdown() {
# 		stopConnectionLostTimer();
# 		if( decoders != null ) {
# 			for( WebSocketWorker w : decoders ) {
# 				w.interrupt();
# 			}
# 		}
#         int i = 74
#         int value = 27
#         int result = 64
# 		if( selector != null ) {
# 			try {
# 				selector.close();
# 			} catch ( IOException e ) {
# 				log.error( "IOException during selector.close", e );
# 				onError( null, e );
# 			}
# 		}
# 		if( server != null ) {
# 			try {
# 				server.close();
# 			} catch ( IOException e ) {
# 				log.error( "IOException during server.close", e );
# 				onError( null, e );
# 			}
# 		}
# 	}

# %% [markdown]
# ### 检测这样获取method body的方法是否总是成功
#
# 结果是总是成功

# %%
for row in dataset:
    code_string = row["code"]
    code_string = JavaParser.wrap_java_code(code_string)

    tree = self_parser.parse(bytes(code_string, "utf8"))
    root_node = tree.root_node
    func_body_node = (
        root_node.children[0].children[-1].children[1].child_by_field_name("body")
    )
    if func_body_node == None:
        print("error~!")
        break

# %% [markdown]
# ## DBI:插入死分支

# %%
test_idx = 0

# %%
from numpy import insert
from process_data.utils import DataUtils

target_list = [500,218]
row = dataset[218]
print(f'idx = {test_idx}')
# row = dataset[test_idx]
test_idx += 100

code_string = row["code"]
code_string = JavaParser.wrap_java_code(code_string)
# print(code_string)

tree = self_parser.parse(bytes(code_string, "utf8"))
root_node = tree.root_node

func_body_node = (
    root_node.children[0].children[-1].children[1].child_by_field_name("body")
)
print(func_body_node.text.decode("utf8"))

# 确定需要继承的缩进量
insert_indent_count = ParserUtils.get_node_indent_count(func_body_node.children[1], code_string)
print(f"insert indent = {insert_indent_count}")

insert_body = DataUtils.get_dead_if_body("java", " " * insert_indent_count)
print(insert_body.encode())
# print(insert_body)


# 给原body做缩进
code_lines = code_string.split("\n")
## 确定起始位置
move_start_line = func_body_node.start_point[0] + 1
move_end_line = func_body_node.end_point[0] + 1
## 加tab移动
for i in range(move_start_line, move_end_line):
    code_lines[i] = "    " + code_lines[i]

random_case = random.randint(0, 1)
if random_case == 0:
    # 插入 if true & else
    if_stmt = f"{' '*insert_indent_count}if (true) {{"
    print(if_stmt.encode())
    code_lines.insert(move_start_line, if_stmt)
    else_stmt = (
        f'{" " *insert_indent_count}else {{{insert_body}\n{" "*insert_indent_count}}}\n}}'
    )
    code_lines.insert(move_end_line + 1, else_stmt)
else:
    ## 插入 if false & else
    front_stmt = f"{' '*insert_indent_count}if (false) {{{insert_body}\n{' '*insert_indent_count}}} else {{"
    code_lines.insert(move_start_line, front_stmt)
    code_lines.insert(move_end_line + 2,  "}")
# print("\n".join(code_lines))
new_blob = "\n".join(code_lines)
new_code_string = JavaParser.unwrap_java_code(new_blob)
DataUtils.display_before_and_after(code_string, new_code_string)
# Out:
# idx = 200
# {
# 		if (logger.isDebugEnabled()) {
# 			logger.debug("Determining Websphere security name for subject " + subject);
# 		}
# 		String userSecurityName = null;
# 		if (subject != null) {
# 			// SEC-803
# 			Object credential = subject.getPublicCredentials(getWSCredentialClass())
# 					.iterator().next();
# 			if (credential != null) {
# 				userSecurityName = (String) invokeMethod(getSecurityNameMethod(),
# 						credential);
# 			}
# 		}
# 		if (logger.isDebugEnabled()) {
# 			logger.debug("Websphere security name is " + userSecurityName
# 					+ " for subject " + subject);
# 		}
# 		return userSecurityName;
# 	}
# insert indent = 8
# b'\n            return Math.sin(Math.PI * x) / (Math.PI * x);'
# before handle:
# class CLS {
# private static String getSecurityName(final Subject subject) {
# 		if (logger.isDebugEnabled()) {
# 			logger.debug("Determining Websphere security name for subject " + subject);
# 		}
# 		String userSecurityName = null;
# 		if (subject != null) {
# 			// SEC-803
# 			Object credential = subject.getPublicCredentials(getWSCredentialClass())
# 					.iterator().next();
# 			if (credential != null) {
# 				userSecurityName = (String) invokeMethod(getSecurityNameMethod(),
# 						credential);
# 			}
# 		}
# 		if (logger.isDebugEnabled()) {
# 			logger.debug("Websphere security name is " + userSecurityName
# 					+ " for subject " + subject);
# 		}
# 		return userSecurityName;
# 	}
# }
# after handle:
# private static String getSecurityName(final Subject subject) {
#         if (false) {
#             return Math.sin(Math.PI * x) / (Math.PI * x);
#         } else {
#     		if (logger.isDebugEnabled()) {
#     			logger.debug("Determining Websphere security name for subject " + subject);
#     		}
#     		String userSecurityName = null;
#     		if (subject != null) {
#     			// SEC-803
#     			Object credential = subject.getPublicCredentials(getWSCredentialClass())
#     					.iterator().next();
#     			if (credential != null) {
#     				userSecurityName = (String) invokeMethod(getSecurityNameMethod(),
#     						credential);
#     			}
#     		}
#     		if (logger.isDebugEnabled()) {
#     			logger.debug("Websphere security name is " + userSecurityName
#     					+ " for subject " + subject);
#     		}
#     		return userSecurityName;
#     	}
# }

# %% [markdown]
# ### 检查body最后的}是不是独立成行

# %%
### 检查body最后的}是不是独立成行

for idx, row in enumerate(dataset):
    code_string = row["code"]
    code_string = JavaParser.wrap_java_code(code_string)
    tree = self_parser.parse(bytes(code_string, "utf8"))
    root_node = tree.root_node
    func_body_node = (
        root_node.children[0].children[-1].children[1].child_by_field_name("body")
    )
    body_code_string = func_body_node.text.decode("utf8")
    
    body_code_lines = body_code_string.split("\n")
    last_line = body_code_lines[-1]
    last_line_strip = last_line.replace('}',' ').strip()
    if last_line_strip != "":
        print(f'idx = {idx}')
        print(last_line.encode())
        # print(sttp.encode())
        # print(func_body_node.text.decode("utf8"))
        # break
# Out:
# idx = 9788
# b'    jcasType.ll_cas.ll_setDoubleValue(addr, ((Summary_Type)jcasType).casFeatCode_score, v);}'
# idx = 9789
# b'    return (StringList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((Summary_Type)jcasType).casFeatCode_variants)));}'
# idx = 9790
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((Summary_Type)jcasType).casFeatCode_variants, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9791
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Question_Type)jcasType).casFeatCode_questionType);}'
# idx = 9792
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Question_Type)jcasType).casFeatCode_questionType, v);}'
# idx = 9793
# b'    return (Token)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((Focus_Type)jcasType).casFeatCode_token)));}'
# idx = 9794
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Token_Type)jcasType).casFeatCode_depLabel);}'
# idx = 9795
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Token_Type)jcasType).casFeatCode_depLabel, v);}'
# idx = 9796
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Token_Type)jcasType).casFeatCode_semanticType);}'
# idx = 9797
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Token_Type)jcasType).casFeatCode_semanticType, v);}'
# idx = 9798
# b'    return (StringArray)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((Document_Type)jcasType).casFeatCode_sections)));}'
# idx = 9799
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((Document_Type)jcasType).casFeatCode_sections, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9800
# b'    return jcasType.ll_cas.ll_getStringArrayValue(jcasType.ll_cas.ll_getRefValue(addr, ((Document_Type)jcasType).casFeatCode_sections), i);}'
# idx = 9801
# b'    jcasType.ll_cas.ll_setStringArrayValue(jcasType.ll_cas.ll_getRefValue(addr, ((Document_Type)jcasType).casFeatCode_sections), i, v);}'
# idx = 9802
# b'    return (StringList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((Concept_Type)jcasType).casFeatCode_uris)));}'
# idx = 9803
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((Concept_Type)jcasType).casFeatCode_uris, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9804
# b'    return (FSList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((Concept_Type)jcasType).casFeatCode_types)));}'
# idx = 9805
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((Concept_Type)jcasType).casFeatCode_types, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9806
# b'    return (Annotation)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((AnswerType_Type)jcasType).casFeatCode_targetType)));}'
# idx = 9807
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((AnswerType_Type)jcasType).casFeatCode_targetType, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9808
# b'    return jcasType.ll_cas.ll_getIntValue(addr, ((SearchResult_Type)jcasType).casFeatCode_rank);}'
# idx = 9809
# b'    jcasType.ll_cas.ll_setIntValue(addr, ((SearchResult_Type)jcasType).casFeatCode_rank, v);}'
# idx = 9810
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((SearchResult_Type)jcasType).casFeatCode_queryString);}'
# idx = 9811
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((SearchResult_Type)jcasType).casFeatCode_queryString, v);}'
# idx = 9812
# b'    return (FSArray)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((SearchResult_Type)jcasType).casFeatCode_candidateAnswers)));}'
# idx = 9813
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((SearchResult_Type)jcasType).casFeatCode_candidateAnswers, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9814
# b'    return (CandidateAnswerVariant)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefArrayValue(jcasType.ll_cas.ll_getRefValue(addr, ((SearchResult_Type)jcasType).casFeatCode_candidateAnswers), i)));}'
# idx = 9815
# b'    jcasType.ll_cas.ll_setRefArrayValue(jcasType.ll_cas.ll_getRefValue(addr, ((SearchResult_Type)jcasType).casFeatCode_candidateAnswers), i, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9816
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Search_Type)jcasType).casFeatCode_query);}'
# idx = 9817
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Search_Type)jcasType).casFeatCode_query, v);}'
# idx = 9818
# b'    return (FSArray)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((Search_Type)jcasType).casFeatCode_hitList)));}'
# idx = 9819
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((Search_Type)jcasType).casFeatCode_hitList, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9820
# b'    return (SearchResult)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefArrayValue(jcasType.ll_cas.ll_getRefValue(addr, ((Search_Type)jcasType).casFeatCode_hitList), i)));}'
# idx = 9821
# b'    jcasType.ll_cas.ll_setRefArrayValue(jcasType.ll_cas.ll_getRefValue(addr, ((Search_Type)jcasType).casFeatCode_hitList), i, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9822
# b'    return (AbstractQuery)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((Search_Type)jcasType).casFeatCode_abstractQuery)));}'
# idx = 9823
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((Search_Type)jcasType).casFeatCode_abstractQuery, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9824
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Search_Type)jcasType).casFeatCode_searchId);}'
# idx = 9825
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Search_Type)jcasType).casFeatCode_searchId, v);}'
# idx = 9826
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Passage_Type)jcasType).casFeatCode_docId, v);}'
# idx = 9827
# b'    return jcasType.ll_cas.ll_getIntValue(addr, ((Passage_Type)jcasType).casFeatCode_offsetInBeginSection);}'
# idx = 9828
# b'    jcasType.ll_cas.ll_setIntValue(addr, ((Passage_Type)jcasType).casFeatCode_offsetInBeginSection, v);}'
# idx = 9829
# b'    return jcasType.ll_cas.ll_getIntValue(addr, ((Passage_Type)jcasType).casFeatCode_offsetInEndSection);}'
# idx = 9830
# b'    jcasType.ll_cas.ll_setIntValue(addr, ((Passage_Type)jcasType).casFeatCode_offsetInEndSection, v);}'
# idx = 9831
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Passage_Type)jcasType).casFeatCode_beginSection);}'
# idx = 9832
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Passage_Type)jcasType).casFeatCode_beginSection, v);}'
# idx = 9833
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Passage_Type)jcasType).casFeatCode_endSection);}'
# idx = 9834
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Passage_Type)jcasType).casFeatCode_endSection, v);}'
# idx = 9835
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Passage_Type)jcasType).casFeatCode_aspects);}'
# idx = 9836
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Passage_Type)jcasType).casFeatCode_aspects, v);}'
# idx = 9837
# b'    return (Triple)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((TripleSearchResult_Type)jcasType).casFeatCode_triple)));}'
# idx = 9838
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((TripleSearchResult_Type)jcasType).casFeatCode_triple, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9839
# b'    return (Triple)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((PassageFromRelation_Type)jcasType).casFeatCode_sourceRelation)));}'
# idx = 9840
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((PassageFromRelation_Type)jcasType).casFeatCode_sourceRelation, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9841
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Triple_Type)jcasType).casFeatCode_subject);}'
# idx = 9842
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Triple_Type)jcasType).casFeatCode_subject, v);}'
# idx = 9843
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((Triple_Type)jcasType).casFeatCode_predicate);}'
# idx = 9844
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((Triple_Type)jcasType).casFeatCode_predicate, v);}'
# idx = 9845
# b'    return jcasType.ll_cas.ll_getBooleanValue(addr, ((Triple_Type)jcasType).casFeatCode_isObjUri);}'
# idx = 9846
# b'    jcasType.ll_cas.ll_setBooleanValue(addr, ((Triple_Type)jcasType).casFeatCode_isObjUri, v);}'
# idx = 9847
# b'    return (QueryOperator)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((ComplexQueryConcept_Type)jcasType).casFeatCode_operator)));}'
# idx = 9848
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((ComplexQueryConcept_Type)jcasType).casFeatCode_operator, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9849
# b'    return (FSList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((ComplexQueryConcept_Type)jcasType).casFeatCode_operatorArgs)));}'
# idx = 9850
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((ComplexQueryConcept_Type)jcasType).casFeatCode_operatorArgs, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9851
# b'    return (Concept)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((ConceptMention_Type)jcasType).casFeatCode_concept)));}'
# idx = 9852
# b'    return jcasType.ll_cas.ll_getDoubleValue(addr, ((ConceptMention_Type)jcasType).casFeatCode_score);}'
# idx = 9853
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((CandidateAnswerOccurrence_Type)jcasType).casFeatCode_text);}'
# idx = 9854
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((CandidateAnswerOccurrence_Type)jcasType).casFeatCode_text, v);}'
# idx = 9855
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((ConceptType_Type)jcasType).casFeatCode_id);}'
# idx = 9856
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((ConceptType_Type)jcasType).casFeatCode_id, v);}'
# idx = 9857
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((ConceptType_Type)jcasType).casFeatCode_name);}'
# idx = 9858
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((ConceptType_Type)jcasType).casFeatCode_abbreviation);}'
# idx = 9859
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((ConceptType_Type)jcasType).casFeatCode_abbreviation, v);}'
# idx = 9860
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((ConceptSearchResult_Type)jcasType).casFeatCode_concept, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9861
# b'    return (FSList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((Answer_Type)jcasType).casFeatCode_variants)));}'
# idx = 9862
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((Answer_Type)jcasType).casFeatCode_variants, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9863
# b'    return (StringList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((QueryConcept_Type)jcasType).casFeatCode_namedEntityTypes)));}'
# idx = 9864
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((QueryConcept_Type)jcasType).casFeatCode_namedEntityTypes, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9865
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((QueryConcept_Type)jcasType).casFeatCode_conceptType);}'
# idx = 9866
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((QueryConcept_Type)jcasType).casFeatCode_conceptType, v);}'
# idx = 9867
# b'    return (FSList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((CandidateAnswerVariant_Type)jcasType).casFeatCode_occurrences)));}'
# idx = 9868
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((CandidateAnswerVariant_Type)jcasType).casFeatCode_occurrences, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9869
# b'    return (FSList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((AbstractQuery_Type)jcasType).casFeatCode_concepts)));}'
# idx = 9870
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((AbstractQuery_Type)jcasType).casFeatCode_concepts, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9871
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((AtomicQueryConcept_Type)jcasType).casFeatCode_originalText);}'
# idx = 9872
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((AtomicQueryConcept_Type)jcasType).casFeatCode_originalText, v);}'
# idx = 9873
# b'    return (StringList)(jcasType.ll_cas.ll_getFSForRef(jcasType.ll_cas.ll_getRefValue(addr, ((QueryOperator_Type)jcasType).casFeatCode_args)));}'
# idx = 9874
# b'    jcasType.ll_cas.ll_setRefValue(addr, ((QueryOperator_Type)jcasType).casFeatCode_args, jcasType.ll_cas.ll_getFSRef(v));}'
# idx = 9875
# b'    return jcasType.ll_cas.ll_getStringValue(addr, ((SemanticRole_Type)jcasType).casFeatCode_label);}'
# idx = 9876
# b'    jcasType.ll_cas.ll_setStringValue(addr, ((SemanticRole_Type)jcasType).casFeatCode_label, v);}'

# %% [markdown]
# ### 检查body开头的}的问题

# %%
for idx, row in enumerate(dataset):
    code_string = row["code"]
    code_string = JavaParser.wrap_java_code(code_string)
    tree = self_parser.parse(bytes(code_string, "utf8"))
    root_node = tree.root_node
    func_body_node = (
        root_node.children[0].children[-1].children[1].child_by_field_name("body")
    )
    body_code_string = func_body_node.text.decode("utf8")
    body_code_lines = body_code_string.split("\n")
    first_line = body_code_lines[0]
    first_strip = first_line.strip()
    if first_strip != "{":
        print(f"idx = {idx}")
        print(first_strip.encode())
# Out:
# idx = 538
# b'{ // TODO: Make this method abstract after removing call(Context)'
# idx = 4757
# b'{ // get info from proto message'
# idx = 5391
# b'{  // this may be called from a background thread, or from checkState() request thread'
# idx = 9320
# b'{\t// Get the nns value from the Reference obj and use it as the map key'

# %% [markdown]
# # parso Test

# %%
import parso

from process_data.RobustCodeSum import PythonParsoParser

row = dataset[0]
# print(row["code"])
code = row["code"]
parsed_ast = parso.parse(code, error_recovery=False, version="3.7")
code_tokens, comment_tokens = [], []

func_nodes = list(parsed_ast.iter_funcdefs())

func_node = func_nodes[0]
doc_node = func_node.get_doc_node()

body_block = PythonParsoParser.find_function_body_block(func_node)
body_block_string = PythonParsoParser.get_body_block_string(body_block)
# 每一行加一个\t
body_block_string = "\t" + body_block_string.replace("\n", "\n\t")
# Out:
#     rawurl = []
#     dom = parseString(xml_data)
#     for node in dom.getElementsByTagName('durl'):
#         url = node.getElementsByTagName('url')[0]
#         rawurl.append(url.childNodes[0].data)
#     return rawurl
# 	    rawurl = []
# 	    dom = parseString(xml_data)
# 	    for node in dom.getElementsByTagName('durl'):
# 	        url = node.getElementsByTagName('url')[0]
# 	        rawurl.append(url.childNodes[0].data)
# 	    return rawurl

# %% [markdown]
# # 测试从输出位置load data文件

# %%
# load data
from datasets import load_dataset,load_from_disk

reload_data = load_from_disk('../local_data/second/semantic/IRS/python/CSN')
print(reload_data.shape)
# Out:
# (14917, 12)

# %%
async def renew_lock(self):
    """Renew the message lock.

    This will maintain the lock on the message to ensure
    it is not returned to the queue to be reprocessed. In order to complete (or otherwise settle)
    the message, the lock must be maintained. Messages received via ReceiveAndDelete mode are not
    locked, and therefore cannot be renewed. This operation can also be performed as an asynchronous
    background task by registering the message with an `azure.servicebus.aio.AutoLockRenew` instance.
    This operation is only available for non-sessionful messages.

    :raises: TypeError if the message is sessionful.
    :raises: ~azure.servicebus.common.errors.MessageLockExpired is message lock has already expired.
    :raises: ~azure.servicebus.common.errors.SessionLockExpired if session lock has already expired.
    :raises: ~azure.servicebus.common.errors.MessageAlreadySettled is message has already been settled.
    """
    if hasattr(self._receiver, "locked_until"):
        raise TypeError(
            "Session messages cannot be renewed. Please renew the Session lock instead."
        )
    self._is_live("renew")
    expiry = await self._receiver._renew_locks(
        self.lock_token
    )  # pylint: disable=protected-access
    self._expiry = datetime.datetime.fromtimestamp(expiry[b"expirations"][0] / 1000.0)
# Out:
# 2

# %% [markdown]
# # 测试删除Java注释
#
# 检查后发现CodeSearchNet中的Java数据的tokens数据中也留有注释
#
# 所以决定这里也不做删除注释操作了

# %%
from process_data.RobustCodeSum import PythonParsoParser

row = dataset[323]
code_string = row["code"]
code_tokens = row['code_tokens']
print(' '.join(code_tokens))
# print(code_string)

tree = self_parser.parse(bytes(code_string, "utf8"))
root_node = tree.root_node
comments_node = []
ParserUtils.traverse_type(root_node, comments_node, "comment")
for comment in comments_node:
    print(comment.text.decode("utf8"))
# Out:
# private static boolean overrides ( Method a , Method b ) { // See JLS section 8.4.8.1 int modifiers = b . getModifiers ( ) ; if ( Modifier . isPublic ( modifiers ) || Modifier . isProtected ( modifiers ) ) { return true ; } if ( Modifier . isPrivate ( modifiers ) ) { return false ; } // b must be package-private return a . getDeclaringClass ( ) . getPackage ( ) . equals ( b . getDeclaringClass ( ) . getPackage ( ) ) ; }
